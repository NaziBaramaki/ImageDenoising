# %% [markdown]
# <a href="https://colab.research.google.com/github/NaziBaramaki/ImageDenoising/blob/main/GaussianFunctionTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-75758c91-adbb-487e-aff7-832e958bd264" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-75758c91-adbb-487e-aff7-832e958bd264">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from PIL import Image
img = Image.open('office_noisy.png')
plt.imshow(img)
plt.show()

# %%
# Load the input "office_noisy" image
img = cv2.imread('office_noisy.png')

# %%
# Define the sigma values to test
sigma_values = [0.5, 1, 2, 5, 10, 50]

# %%
import cv2
img = cv2.imread('office_noisy.png')
img_float = img.astype(np.float32) / 255.0
sigma=0.5
# Apply Gaussian smoothing
blurred = cv2.GaussianBlur(img_float, (0, 0), sigma)

# Display the result
plt.imshow(blurred, cmap='gray')
plt.show()

# %%
# Create a figure to display the results
fig, axes = plt.subplots(2, 3, figsize=(12, 8))

# Apply Gaussian smoothing with different sigma values
for i, sigma in enumerate(sigma_values):
    row = i // 3
    col = i % 3
    img_umat = cv2.UMat(img)
    # Apply Gaussian smoothing
    blurred = cv2.GaussianBlur(img_umat, (0, 0), sigma)

    # Convert the blurred image to a compatible data type
    blurred_uint8 = cv2.convertScaleAbs(blurred.get())

    # Display the result
    axes[row, col].imshow(blurred_uint8, cmap='gray')
    axes[row, col].set_title(f'Sigma = {sigma}')
    axes[row, col].axis('off')

plt.suptitle('Gaussian Smoothing on "office" Image')
plt.tight_layout()
plt.show()
